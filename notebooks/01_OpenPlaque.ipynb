# %% [markdown]
# # OpenPlaque
# Load and verify a CCTA study.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !pip -q install SimpleITK pydicom nibabel matplotlib scipy scikit-image

# %%
import requests
url='https://raw.githubusercontent.com/pazzani/OpenPlaque/main/colab/helpers.py'
r=requests.get(url)
open('helpers.py','w').write(r.text)
from helpers import *

# %%
image, volume, files = load_cta(zip_name='Series7_BestDiast.zip')

# %%
show_slices(volume)
