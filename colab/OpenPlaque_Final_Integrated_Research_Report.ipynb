# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# Controls — immediately after Drive mount; safe for Runtime → Run all
DRIVE_ROOT='/content/drive/MyDrive/OpenPlaque'
OUTPUT_ROOT=DRIVE_ROOT + '/Final_Integrated_Research_Report_v1'

# %% [markdown]
# # OpenPlaque — Final Integrated Coronary Research Report
#
# This notebook consolidates the completed canonical anatomy, 5-fold plaque-confidence atlas, locked RCA PCAT analysis, and corrected longitudinal plaque/PCAT fusion. It explicitly does **not** claim source-space TPV or full 3-D plaque localization.

# %%
# !pip -q install pandas numpy matplotlib pytest
import shutil, sys
from pathlib import Path
repo=Path('/content/OpenPlaque')
if repo.exists(): shutil.rmtree(repo)
# !git clone -q --depth 1 --branch final-integrated-research-report-from-main https://github.com/pazzani/OpenPlaque.git /content/OpenPlaque
sys.path.insert(0,'/content/OpenPlaque/src')

# %%
# Unit checks before reading Drive artifacts
# !cd /content/OpenPlaque && PYTHONPATH=/content/OpenPlaque/src pytest -q tests/test_final_integrated_research_report.py

# %%
from openplaque.final_integrated_research_report import run
result = run(drive_root=DRIVE_ROOT, output_root=OUTPUT_ROOT)
print('STATUS:', result['status'])
print('SCIENTIFIC STATUS:', result['scientific_status'])
s=result['summary']
print('RCA canonical length:', round(s['anatomy']['RCA']['length_mm'],2),'mm')
print('LAD canonical length:', round(s['anatomy']['LAD']['length_mm'],2),'mm')
print('RCA PCAT mean:', round(s['rca_pcat_lock']['mean_hu'],2),'HU')
print('RCA PCAT-window majority plaque bins:', s['longitudinal_fusion']['RCA']['pcat_window_majority_bins'])
print('REPORT:', result['report'])
print('ZIP:', result['zip'])
print('Drive search: https://drive.google.com/drive/u/0/search?q=OPENPLAQUE_FINAL_INTEGRATED_RESEARCH_REPORT_BACK.zip')
