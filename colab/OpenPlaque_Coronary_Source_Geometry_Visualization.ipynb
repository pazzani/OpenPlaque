# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# Controls
REUSE_EXISTING=True
DRIVE_ROOT='/content/drive/MyDrive/OpenPlaque'
OUTPUT_ROOT=DRIVE_ROOT + '/Coronary_Source_Geometry_Visualization_v1'

# %% [markdown]
# # OpenPlaque — Source-CCTA coronary geometry integration
# Compares the independent TotalSegmentator coronary masks with frozen source-volume RCA/LAD/secondary centerlines in true LPS coordinates, and adds whole-heart/aortic context. No plaque masks are overlaid here because the plaque nnU-Net masks live in curved-series coordinates.

# %%
# !pip -q install SimpleITK scipy scikit-image pandas matplotlib
import shutil, sys
from pathlib import Path
repo=Path('/content/OpenPlaque')
if repo.exists(): shutil.rmtree(repo)
# !git clone -q --depth 1 --branch coronary-source-geometry-visualization-from-main https://github.com/pazzani/OpenPlaque.git /content/OpenPlaque
sys.path.insert(0,'/content/OpenPlaque/src')

# %%
from openplaque.coronary_source_geometry_viz import run
result = run(DRIVE_ROOT, OUTPUT_ROOT)
print(result['metrics'])
print('REPORT:', result['report'])
print('ZIP:', result['zip'])
print('Drive search: https://drive.google.com/drive/u/0/search?q=OPENPLAQUE_CORONARY_SOURCE_GEOMETRY_VISUALIZATION_REPORT_BACK.zip')
