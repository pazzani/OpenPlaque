# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# Controls
DRIVE_ROOT='/content/drive/MyDrive/OpenPlaque'
OUTPUT_ROOT=DRIVE_ROOT + '/PCAT_Plaque_Integrated_Report_v1'

# %% [markdown]
# # OpenPlaque — Coronary inflammation + plaque report
# Reuses the locked canonical RCA PCAT analysis and the completed plaque ensemble. If the plaque confidence-atlas notebook has already been run, this report automatically adds its 5/5 and 4+/5 confidence volumes and native longitudinal profile. Source PCAT and curved-series plaque coordinates are deliberately kept separate; this notebook does not claim Caristo FAI-Score or CaRi-Heart Risk.

# %%
# !pip -q install pandas matplotlib numpy
import shutil, sys
from pathlib import Path
repo=Path('/content/OpenPlaque')
if repo.exists(): shutil.rmtree(repo)
# !git clone -q --depth 1 --branch pcat-plaque-integrated-report-from-main https://github.com/pazzani/OpenPlaque.git /content/OpenPlaque
sys.path.insert(0,'/content/OpenPlaque/src')

# %%
from openplaque.pcat_plaque_integrated_report import run
result = run(DRIVE_ROOT, OUTPUT_ROOT)
print(result['inflammation_summary'])
print(result['plaque_fold_stats'])
print('REPORT:', result['report'])
print('ZIP:', result['zip'])
print('Drive search: https://drive.google.com/drive/u/0/search?q=OPENPLAQUE_PCAT_PLAQUE_INTEGRATED_REPORT_BACK.zip')
