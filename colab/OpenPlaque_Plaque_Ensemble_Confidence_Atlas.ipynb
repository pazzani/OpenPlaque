# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# Controls
DRIVE_ROOT='/content/drive/MyDrive/OpenPlaque'
OUTPUT_ROOT=DRIVE_ROOT + '/Plaque_Ensemble_Confidence_Atlas_v1'

# %% [markdown]
# # OpenPlaque — 5-fold plaque confidence atlas
# Builds 0/5–5/5 plaque-vote maps, high-confidence masks, majority-vote lesion components, and automatically selected informative slices for RCA and LAD. These outputs remain in the plaque model's native curved vessel-series coordinates; they are not falsely overlaid onto source CCTA.

# %%
# !pip -q install SimpleITK scipy pandas matplotlib
import shutil, sys
from pathlib import Path
repo=Path('/content/OpenPlaque')
if repo.exists(): shutil.rmtree(repo)
# !git clone -q --depth 1 --branch plaque-ensemble-confidence-atlas-from-main https://github.com/pazzani/OpenPlaque.git /content/OpenPlaque
sys.path.insert(0,'/content/OpenPlaque/src')

# %%
from openplaque.plaque_ensemble_confidence import run
result = run(DRIVE_ROOT, OUTPUT_ROOT)
print(result['summary'])
print('Majority-vote lesion components:', result['n_lesions'])
print('REPORT:', result['report'])
print('ZIP:', result['zip'])
print('Drive search: https://drive.google.com/drive/u/0/search?q=OPENPLAQUE_PLAQUE_ENSEMBLE_CONFIDENCE_ATLAS_REPORT_BACK.zip')
